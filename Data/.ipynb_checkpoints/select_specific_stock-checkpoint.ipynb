# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/amily/Desktop/stock.csv")
df['Date'] = pd.to_datetime(df['Date'])

# Filter for Amazon (AMZN) stocks within the date range
filtered_df = df[
    (df['Ticker'] == 'AMZN') & 
    (df['Date'] >= '2021-12-31') & 
    (df['Date'] <= '2023-01-01')
]

filtered_df['Daily_Return'] = (filtered_df['Close'] - filtered_df['Close'].shift(1)) / filtered_df['Close'].shift(1) 
#filtered_df[["Date","Ticker","Industry"]]
filtered_df = filtered_df[
    (df['Ticker'] == 'AMZN') & 
    (df['Date'] >= '2022-01-01') & 
    (df['Date'] <= '2023-01-01')
]
filtered_df.to_csv("/Users/amily/Desktop/amazon_stock.csv")
filtered_df
# Out:
# /var/folders/bf/mf9fw9915q98qdc0k4pv6gnr0000gn/T/ipykernel_18497/4134621777.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Daily_Return'] = (filtered_df['Close'] - filtered_df['Close'].shift(1)) / filtered_df['Close'].shift(1)
# /var/folders/bf/mf9fw9915q98qdc0k4pv6gnr0000gn/T/ipykernel_18497/4134621777.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_df = filtered_df[
#                           Date   Adj Close       Close        High  \
# 5662 2022-01-03 00:00:00+00:00  170.404495  170.404495  170.703506
# 5663 2022-01-04 00:00:00+00:00  167.522003  167.522003  171.399994
# 5664 2022-01-05 00:00:00+00:00  164.356995  164.356995  167.126495
# ...
