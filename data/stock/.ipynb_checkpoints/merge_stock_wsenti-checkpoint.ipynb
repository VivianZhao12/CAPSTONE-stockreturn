# %%
import os
import pandas as pd

# %%
home_dir = os.path.expanduser('~')
stock_path = os.path.join(home_dir, "CAPSTONE-stockreturn/data/stock/cvs_stock.csv")
sentiment_path = os.path.join(home_dir, "CAPSTONE-stockreturn/data/sentiment/CVS_merged_file.csv")

stock_df = pd.read_csv(stock_path)
sentiment_df = pd.read_csv(sentiment_path)

# %%
stock_df['Date'] = pd.to_datetime(stock_df['Date'])
sentiment_df['Date'] = pd.to_datetime(sentiment_df['Date']).dt.tz_localize('UTC')

# %%
merged_df = pd.merge(stock_df, sentiment_df, on='Date', how='outer')
merged_df = merged_df.dropna()
merged_df
# Out:
#                           Date  Adj Close      Close       High        Low  \
# 124  2020-06-02 00:00:00+00:00  58.320549  66.839996  67.309998  65.410004
# 125  2020-06-03 00:00:00+00:00  58.329269  66.849998  67.680000  66.239998
# 126  2020-06-04 00:00:00+00:00  58.050053  66.529999  66.720001  65.949997
# 127  2020-06-05 00:00:00+00:00  59.638069  68.349998  69.190002  67.129997
# 128  2020-06-08 00:00:00+00:00  61.618752  70.620003  70.639999  68.160004
# ...                        ...        ...        ...        ...        ...
# 1461 2025-01-03 00:00:00+00:00  45.770000  45.770000  46.259998  44.139999
# 1464 2025-01-06 00:00:00+00:00  45.820000  45.820000  47.169998  45.689999
# 1465 2025-01-07 00:00:00+00:00  45.779999  45.779999  46.820000  45.570000
# 1466 2025-01-08 00:00:00+00:00  46.009998  46.009998  46.180000  44.919998
# 1468 2025-01-10 00:00:00+00:00  48.009998  48.009998  48.099998  46.340000
#
#            Open      Volume Ticker Industry  Daily_Return  Sentiment_Score
# 124   65.639999   5463700.0    CVS   Health      0.018282         0.564825
# 125   67.139999   6102400.0    CVS   Health      0.000150         0.489646
# 126   66.290001   5468900.0    CVS   Health     -0.004787         0.531113
# 127   67.279999   8598400.0    CVS   Health      0.027356         0.442003
# 128   68.199997   8556300.0    CVS   Health      0.033212         0.551922
# ...         ...         ...    ...      ...           ...              ...
# 1461  44.720001  12202300.0    CVS   Health      0.035052         0.484684
# 1464  46.080002  16462500.0    CVS   Health      0.001092         0.309375
# 1465  46.320000  10244500.0    CVS   Health     -0.000873         0.399796
# 1466  45.650002  14272800.0    CVS   Health      0.005024         0.474558
# 1468  46.419998  16813800.0    CVS   Health      0.043469         0.460102
#
# [1160 rows x 11 columns]

# %%
output_dir = os.path.join(home_dir, "CAPSTONE-stockreturn/data/stock")
output_path = os.path.join(output_dir, "cvs_stock_wsenti.csv")
merged_df.to_csv(output_path, index=False)
